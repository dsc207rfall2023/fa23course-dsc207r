# %% [markdown]
# **Assignment notes -**
# 1. You may use any visualization tool - seaborn/matplotlib for a task
# 2. Sample outputs are provided but your output may vary based on choice of library and parameters.
# 3. Use the mandatory parameter values wherever specified

# %% [markdown]
# ## Import pandas, numpy, matplotlib.pyplot, seaborn

# %%
#ToDo

# %% [markdown]
# ### 1. Fetch and read data
# In this assignment, we will be working with a dataset of property listings from airbnb - https://raw.githubusercontent.com/iamsharduld/DSC207Datasets/main/Week5/airbnb_sd_listings.csv. As you may have noticed, the file type is csv - comma separated values. **Read this data into a pandas dataframe `listings_df`.** [0.5pt]

# %%
#ToDo

# %% [markdown]
# ### 2. Inspect Data

# %% [markdown]
# 2.1 **Print the shape** of the `listings_df` DataFrame. [0.5pt]

# %%
#ToDo

# %% [markdown]
# 2.2 **Display the first 10 entries** in the `listings_df` DataFrame to get an idea of what the columns are and what some values might look like. [0.5pt]

# %%
#ToDo

# %% [markdown]
# 2.3 **Find number of unique hosts** in the `listings_df` dataframe. [0.5pt]

# %%
#ToDo

# %% [markdown]
# 2.4 **Find the number of listings that offer only shared rooms in `listings_df` dataframe.** [0.5pt]

# %%
#ToDo

# %% [markdown]
# 2.5 **Describe the dataset (Recall describe( ) function from Week 3)** [0.5pt]

# %%
#ToDo

# %% [markdown]
# ### 3. Plotting Data

# %% [markdown]
# #### 3.1 Plot histogram of AirBnB prices in San Diego.  [1pt]
#
# 1.   This histogram should have price ranges on the x-axis and counts on the y-axis.
# 2.   Choose an appropriate color and edge-color combination.
# 3.   Choose an appropriate value for bin
# 4.   Provide axis labels
# 5.   Provide a chart title/caption
#
# ![image.png](data:image/png;base64,...)

# %%
#ToDo

# %% [markdown]
# #### 3.2 Inference
#
# **What insight does this visualization provide? How does the value of bin change the visualization (you may try a low and high value of bin and discuss the pros and cons of both).** [0.5pt]

# %%
#ToDo

# %% [markdown]
# #### 3.3 Create a scatterplot of `price` on X-Axis vs `number_of_reviews` on Y-Axis for first 1000 values in the dataset. [1pt]
# 1.   Provide axis labels
# 2.   Provide a chart title/caption
#
# ![image.png](data:image/png;base64,...)

# %%
#ToDo

# %% [markdown]
# #### 3.4 Inference
#
# **What is the trend you observe from the above visualization? Do you think it makes sense from a real world perspective?** [0.5pt]

# %%
#ToDo

# %% [markdown]
# #### 3.5 Bar graphs
# Bar graphs are useful in plotting data for categorical variables like room_type.

# %% [markdown]
# Find the exact count for each room type (Recall value_counts( ) from week 3) and use it to create a horizontal bar chart. [1 pt]
# 1. Provide axis labels
# 2. Provide a chart title/caption
#
# ![image.png](data:image/png;base64,...)

# %%
#ToDo

# %% [markdown]
# ### 4. Subplots
#
# Subplots allow us to have several graphs in one view which may help us analyse quickly and efficiently. Our goal is to create 2 subplots to understand trends by neighbourhood in San Diego. Let us start by setting up our subplots.

# %%
#Run this cell
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# %% [markdown]
# #### Bar Graph
# 1. For the first of 2 subplots, Plot top 10 neighbourhoods in San Diego with most number of AirBnB units available. Hence this would be a bar graph with neighbourhood and counts. This may require 2 steps -
#
# ####  4.1. Extracting the df for `top_10_neighbourhoods`. (Recall value_counts() and slicing from Week 3) [0.5pt]
#
#  #### 4.2. Plot the graph [1pt]
#   1.   Provide axis labels
#   2.   Provide a chart title/caption
#   3.   Set the ax parameter to axes[0] to set it to the first subplot
#   4.   If done correctly, we should see a graph with a non-increasing count of airbnb by neighbourhoods.
#
# ![image.png](data:image/png;base64,...)

# %%
#ToDo

# %% [markdown]
# #### Boxplot
#
# For the second subplot, we want to find a distribution of prices of airbnbs in the `top_10_neighbourhoods`. To perform this you may consider 2 steps -
#
# ####  4.3. Creating a `filtered_df` that has all the data for only the `top_10_neighbourhoods`. Hint - the isin() method may be useful here. [0.5pt]
#
# ####  4.4. Plot boxplot with x-axis as neighbourhood and y-axis as price. [1pt]
#   1.   Provide axis labels
#   2.   Provide a chart title/caption
#   3.   Set the ax parameter to axes[1] to set it to the second subplot
#   4.   Set parameters `showfliers = False` to get a cleaner graph by removing the outliers.
#
# ![image.png](data:image/png;base64,...)

# %%
#ToDo

# %% [markdown]
# #### 4.3 **Print the combined subplot by printing `fig`.** The report should contain both the graphs created in part 4 as subplots (as shown below)
# ![image.png](data:image/png;base64,...)

# %%
#Run this cell
fig

# %% [markdown]
# ### 5. Overlay longitude and lattitude with color as price gradient on San Diego Map Using Plotly [No points].
#
# Run this cell to see an advanced usage of plotly to generate a geographical map.
# Use data for 10 most popular neighbourhoods found in 3.1

# %%
import plotly.express as px

fig = px.scatter_mapbox(filtered_df, color=filtered_df['price'], lat="latitude", lon="longitude",
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
                        
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bbf35ced-f082-4903-bc67-4e3cb8897fcd" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbf35ced-f082-4903-bc67-4e3cb8897fcd")) {                    Plotly.newPlot(                        "bbf35ced-f082-4903-bc67-4e3cb8897fcd",                        [{"hovertemplate":"latitude=%{lat}<br>longitude=%{lon}<br>price=%{marker.color}<extra></extra>","lat":[32.78481,32.80751,32.81301,32.80583,32.80885,32.74699,32.74827,32.74715,32.81321,32.74779,32.79783,32.80751,32.80934,32.79644,32.76411,32.74109,32.81041,32.84006,32.76757,32.75819,32.75259,32.73183,32.74277,32.75031,32.73464,32.74957,32.75152,32.75711,32.80135,32.74359,32.75103,32.83452,32.74271,32.74966,32.82787,32.71941,32.78917,32.73608,32.83277,32.75238,32.7873,32.77816,32.81561,32.80451,32.73408,32.74217,32.82898,32.82901,32.74259,32.74566,32.81244,32.71553,32.83984,32.74323,32.80756,32.7159,32.73861,32.79429,32.75668,32.74411,32.84279,32.80769,32.7505,32.70918,32.75994,32.71724,32.79545,32.80691,32.74474,32.76817,32.79113,32.78673,32.75117,32.82857,32.82714,32.72853,32.79906,32.70962,32.79923,32.80074,32.8009,32.79963,32.80122,32.80108,32.79835,32.79644,32.79619,32.79824,32.79911,32.79943,32.80078,32.80114,32.80111,32.8009,32.80119,32.