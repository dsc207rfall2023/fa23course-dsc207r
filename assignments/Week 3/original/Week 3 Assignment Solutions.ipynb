# %% [markdown]
# ### Import pandas and numpy

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### 1.1 Fetch and read book data
# In this assignment, we will be working with a dataset of books - https://raw.githubusercontent.com/iamsharduld/DSC207Datasets/main/Week3/books_hw.csv. As you may have noticed, the file type is csv - comma separated values. **Read this data into a pandas dataframe `books`.** (Hint - It might be useful to look into [documentation](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.read_csv.html) for read csv files. If you come across some 'bad' lines in the dataset, the parameter `error_bad_lines` may be useful)) [0.5pt]

# %%
dataset_URL = "https://raw.githubusercontent.com/iamsharduld/DSC207Datasets/main/Week3/books_hw.csv"
books = pd.read_csv(dataset_URL, error_bad_lines = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'

# %% [markdown]
# **To verify that `books` contains data, print the first 10 rows of the dataset.** Verify the same with CSV file. [0.5pt]

# %%
books.head(10)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6      10       Harry Potter Collection (Harry Potter  #1-6)
# 7      12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8      13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9      14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 5      W. Frederick Zimmerman            3.74  0976540606  9780976540601
# 6                J.K. Rowling            4.73  0439827604  9780439827607
# 7               Douglas Adams            4.38  0517226952  9780517226957
# 8               Douglas Adams            4.38  0345453743  9780345453747
# 9               Douglas Adams            4.22  1400052920  9781400052929
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
# 5         en-US          152             19                   1
# 6           eng         3342          28242                 808
# 7           eng          815           3628                 254
# 8           eng          815         249558                4080
# 9           eng          215           4930                 460
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic
# 5        4/26/2005     Nimble Books
# 6        9/12/2005       Scholastic
# 7        11/1/2005   Gramercy Books
# 8        4/30/2002    Del Rey Books
# 9         8/3/2004            Crown

# %% [markdown]
# ### 1.2 Change Index to bookID
# In the above dataframe, you can see that there is an index before the first column `bookID`. Instead we can have bookID as the index for better searching and filtering. **Change the index of `books` to `bookID`.** (Hint - make sure the you are applying the changes to the same dataframe) [0.5pt]

# %%
books.set_index('bookID', inplace=True)

# %% [markdown]
# To verify change in index, print the first 10 rows of the updated dataframe `books`. [0.5pt]

# %%
books.head(10)
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 9       Unauthorized Harry Potter Book Seven News: "Ha...
# 10           Harry Potter Collection (Harry Potter  #1-6)
# 12      The Ultimate Hitchhiker's Guide: Five Complete...
# 13      The Ultimate Hitchhiker's Guide to the Galaxy ...
# 14      The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 4                     J.K. Rowling            4.42  0439554896  9780439554893
# 5       J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 8       J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 9           W. Frederick Zimmerman            3.74  0976540606  9780976540601
# 10                    J.K. Rowling            4.73  0439827604  9780439827607
# 12                   Douglas Adams            4.38  0517226952  9780517226957
# 13                   Douglas Adams            4.38  0345453743  9780345453747
# 14                   Douglas Adams            4.22  1400052920  9781400052929
#
#        language_code    num_pages  ratings_count  text_reviews_count  \
# bookID
# 1                eng          652        2095690               27591
# 2                eng          870        2153167               29221
# 4                eng          352           6333                 244
# 5                eng          435        2339585               36325
# 8                eng         2690          41428                 164
# 9              en-US          152             19                   1
# 10               eng         3342          28242                 808
# 12               eng          815           3628                 254
# 13               eng          815         249558                4080
# 14               eng          215           4930                 460
#
#        publication_date        publisher
# bookID
# 1             9/16/2006  Scholastic Inc.
# 2              9/1/2004  Scholastic Inc.
# 4             11/1/2003       Scholastic
# 5              5/1/2004  Scholastic Inc.
# 8             9/13/2004       Scholastic
# 9             4/26/2005     Nimble Books
# 10            9/12/2005       Scholastic
# 12            11/1/2005   Gramercy Books
# 13            4/30/2002    Del Rey Books
# 14             8/3/2004            Crown

# %% [markdown]
# ### 1.3 Print the total samples(rows) in dataset [0.5pt]

# %%
len(books)
# Out:
# 11123

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### 2.1 Filtering dataframes

# %% [markdown]
# We may want the ability to get data based on certain criteria to perform analysis or derive statistics. Get all rows from the dataframe `books` for which author is "J.R.R. Tolkien" and store it in `booksByTolkien`. [0.5pt]

# %%
booksByTolkien=books.loc[books['authors']=="J.R.R. Tolkien"]
booksByTolkien
# Out:
#                                                     title         authors  \
# bookID
# 30      J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...  J.R.R. Tolkien
# 31      The Lord of the Rings (The Lord of the Rings  ...  J.R.R. Tolkien
# 34      The Fellowship of the Ring (The Lord of the Ri...  J.R.R. Tolkien
# 2331    The Lord of the Rings- 3 volumes set (The Lord...  J.R.R. Tolkien
# 5898    The Lord of the Rings (The Lord of the Rings  ...  J.R.R. Tolkien
# 5907                  The Hobbit  or There and Back Again  J.R.R. Tolkien
# 5911                                Poems From The Hobbit  J.R.R. Tolkien
# 5912                  The Hobbit: Or There and Back Again  J.R.R. Tolkien
# 5915                                           The Hobbit  J.R.R. Tolkien
# 7348    Tree and Leaf: Includes Mythopoeia and The Hom...  J.R.R. Tolkien
# 15245   The Return of the King (The Lord of the Rings ...  J.R.R. Tolkien
# 15298   The Return of the King (The Lord of the Rings ...  J.R.R. Tolkien
# 15331   The Fellowship of the Ring (The Lord of the Ri...  J.R.R. Tolkien
# 15336                  The Lord of the Rings / The Hobbit  J.R.R. Tolkien
# 15373   The Return of the King (The Lord of the Rings ...  J.R.R. Tolkien
# 15407   The Lord of the Rings Millennium Edition Boxed...  J.R.R. Tolkien
# 23603                       Tales from the Perilous Realm  J.R.R. Tolkien
#
#         average_rating        isbn         isbn13 language_code    num_pages  \
# bookID
# 30                4.59  0345538374  9780345538376           eng         1728
# 31                4.50  0618517650  9780618517657           eng         1184
# 34                4.36  0618346252  9780618346257           eng          398
# 2331              4.50  0618574999  9780618574995         en-US         1438
# 5898              4.50  0007136587  9780007136582           eng         1200
# 5907              4.27  0618260307  9780618260300           eng          366
# 5911              4.30  0618009345  9780618009343           eng           57
# 5912              4.27  1594130051  9781594130052           eng          481
# 5915              4.27  0261103288  9780261103283           eng          277
# 7348              4.05  0007105045  9780007105045           eng          150
# 15245             4.53  0007171994  9780007171996           eng          554
# 15298             4.53  0618574972  9780618574971         en-US          508
# 15331             4.36  0618574948  9780618574940           eng          506
# 15336             4.59  0007144083  9780007144082           eng         1600
# 15373             4.53  0965307794  9780965307796           eng          440
# 15407             4.50  0618037667  9780618037667           eng         1472
# 23603             4.08  0007149123  9780007149124           eng          178
#
#         ratings_count  text_reviews_count publication_date  \
# bookID
# 30             101233                1550        9/25/2012
# 31               1710                  91       10/21/2004
# 34            2128944               13670         9/5/2003
# 2331              232                   9         6/1/2005
# 5898              682                  43        9/16/2002
# 5907          2530894               32871        8/15/2002
# 5911              169                   5       12/13/1999
# 5912              276                  43         9/1/2003
# 5915             3213                 329        9/17/2007
# 7348             2357                  97         2/5/2001
# 15245             265                   5        11/6/2003
# 15298            1635                  74         6/1/2005
# 15331            1323                 121         6/1/2004
# 15336             141                   5        10/7/2002
# 15373             202                  10         1/1/2001
# 15407             120                   5       10/10/1999
# 23603            3242                 162         9/2/2002
#
#                            publisher
# bookID
# 30                  Ballantine Books
# 31         Houghton Mifflin Harcourt
# 34         Houghton Mifflin Harcourt
# 2331                   Mariner Books
# 5898                       Not Avail
# 5907                Houghton Mifflin
# 5911       Houghton Mifflin Harcourt
# 5912               Large Print Press
# 5915                   HarperCollins
# 7348    HarperCollins Publishers Ltd
# 15245   HarperCollins Publishers Ltd
# 15298                  Mariner Books
# 15331       Houghton Mifflin Company
# 15336        Collins Modern Classics
# 15373    Quality Paperback Book Club
# 15407               Houghton Mifflin
# 23603       HarperCollins Publishers

# %%
books2 = books.append(booksByTolkien, ignore_index=True)
books2

# %% [markdown]
# Print the sum of rating_count in `booksByTolkien` [0.5pt]

# %%
booksByTolkien['ratings_count'].sum()
# Out:
# 4776638

# %% [markdown]
# ### 2.2 Data analysis using dataframes

# %% [markdown]
# Since a dataframe is a collection of large amounts of data, often dealing with numeric data. This data can be used to create aggregations, which is very useful in deriving actionable insights.
#
# **Mean - Find average rating of all books present in the dataset.** [0.5pt]

# %%
books['average_rating'].mean()
# Out:
# 3.9340753393868564

# %% [markdown]
# ### 2.3 Average rating of books written by "J.K. Rowling"
#
# Use the ability of filtering dataframes and find the mean of the filtered dataframe. [1pt]

# %%
books.loc[books['authors']=="J.K. Rowling", 'average_rating'].mean()
# Out:
# 4.513636363636365

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### 3.1 How many unique authors are present in this dataset?
# (Hint - is there a function to do this?) [0.5pt]

# %%
len(books.authors.unique())
# Out:
# 6639

# %% [markdown]
# ### 3.2 What is the maximum average rating for a book in the dataset?
# Store the result in `maxRating`. Print `maxRating`. [0.5pt]

# %%
maxRating = books['average_rating'].max()
maxRating
# Out:
# 5.0

# %% [markdown]
# ### 3.3 Authors of the books which are rated maximum
# One sample data analysis task would be to find the authors who have high rated books. This information could be of great use to a publisher or book store chain.
#
#
# **Store the author name, book title and average rating of the books who have maximum rating, in a dataframe `maxRatedAuthors`. Print `maxRatedAuthors`.** [0.5pt]

# %%
maxRatedAuthors=books.loc[books['average_rating'] == maxRating][['authors', 'title', 'average_rating']]
maxRatedAuthors
# Out:
#                                                   authors  \
# bookID
# 2034                  Aristophanes/F.W. Hall/W.M. Geldart
# 2560                      Julie Sylvester/David Sylvester
# 2843                                       Tara MacCarthy
# 4287                 Middlesex Borough Heritage Committee
# 14741                                          Tim Bogenn
# 17224                                       John  Diamond
# 17830                                     Elena N. Mahlow
# 18184                     Ian        Martin/Katie Elliott
# 19786                                          NOT A BOOK
# 19788                                          NOT A BOOK
# 20954                            Dennis Adler/R.L. Wilson
# 20957                                      R. McL. Wilson
# 23276                                        Ross Garnaut
# 23552                                Todd Davis/Marc Frey
# 25426                     Nicholas    Evans/Rhonda  Evans
# 32823    Chris    Green/Chris Wright/Paul Douglas Gardner
# 36492                                  William C. Dowling
# 36853   Laura Driscoll/Alisa Klayman-Grodsky/Eric     ...
# 38804                                       Keith Donohue
# 39580                                   James E. Campbell
# 39829                                 Sheri Rose Shepherd
# 41639                                    Sara Barton-Wood
#
#                                                     title  average_rating
# bookID
# 2034    Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...             5.0
# 2560                    Willem de Kooning: Late Paintings             5.0
# 2843    Literature Circle Guide: Bridge to Terabithia:...             5.0
# 4287    Middlesex Borough (Images of America: New Jersey)             5.0
# 14741   Zone of the Enders: The 2nd Runner Official St...             5.0
# 17224   The Diamond Color Meditation: Color Pathway to...             5.0
# 17830   Bulgakov's the Master and Margarita: The Text ...             5.0
# 18184   The Complete Theory Fun Factory: Music Theory ...             5.0
# 19786   The Goon Show  Volume 4: My Knees Have Fallen ...             5.0
# 19788   The Goon Show  Volume 11: He's Fallen in the W...             5.0
# 20954                                 Winchester Shotguns             5.0
# 20957   Colossians and Philemon: A Critical and Exeget...             5.0
# 23276                           Taxation of Mineral Rents             5.0
# 23552                         The New Big Book of America             5.0
# 25426   Delwau Duon: Peintiadau Nicholas Evans = Symph...             5.0
# 32823        Fanning the Flame: Bible  Cross  and Mission             5.0
# 36492   Oliver Wendell Holmes in Paris: Medicine  Theo...             5.0
# 36853                  Tyrannosaurus Wrecks (Stanley  #1)             5.0
# 38804       The Irish Anatomist: A Study of Flann O'Brien             5.0
# 39580   The American Campaign: U.S. Presidential Campa...             5.0
# 39829   His Princess Devotional: A Royal Encounter Wit...             5.0
# 41639          Bill Gates: Computer Legend (Famous Lives)             5.0

# %% [markdown]
# **Print the number of max rated authors.** [0.5pt]

# %%
len(maxRatedAuthors)
# Out:
# 22

# %% [markdown]
# ### 3.4 List books whose rating count is greater than 2000 and average rating is more than 4.70
#
# Store this into a dataframe `popularBooks`. Print `popularBooks`. [0.5pt]

# %%
popularBooks = books.loc[(books['average_rating'] > 4.70) & (books['ratings_count'] > 2000)]
popularBooks
# Out:
#                                                     title  \
# bookID
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 10           Harry Potter Collection (Harry Potter  #1-6)
# 24812                      The Complete Calvin and Hobbes
# 24814       It's a Magical World (Calvin and Hobbes  #11)
# 24816   Homicidal Psycho Jungle Cat (Calvin and Hobbes...
# 24820   Calvin and Hobbes: Sunday Pages 1985-1995: An ...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 8       J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 10                    J.K. Rowling            4.73  0439827604  9780439827607
# 24812               Bill Watterson            4.82  0740748475  9780740748479
# 24814               Bill Watterson            4.76  0836221362  9780836221367
# 24816               Bill Watterson            4.72  0836217691  9780836217698
# 24820               Bill Watterson            4.71  0740721356  9780740721359
#
#        language_code    num_pages  ratings_count  text_reviews_count  \
# bookID
# 8                eng         2690          41428                 164
# 10               eng         3342          28242                 808
# 24812            eng         1456          32213                 930
# 24814            eng          176          23875                 303
# 24816            eng          176          15365                 290
# 24820            eng           96           3613                  85
#
#        publication_date                  publisher
# bookID
# 8             9/13/2004                 Scholastic
# 10            9/12/2005                 Scholastic
# 24812          9/6/2005  Andrews McMeel Publishing
# 24814          9/1/1996  Andrews McMeel Publishing
# 24816          9/6/1994  Andrews McMeel Publishing
# 24820         9/17/2001  Andrews McMeel Publishing

# %% [markdown]
# ### Describe the dataset
# We want to use statistics to get a general idea of the dataframe and its numerical values.
#
# Using [describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html), provide the counts, mean, standard deviation, mins, percentiles and maxs of the dataframe `popularBooks`. [0.5pt]

# %%
popularBooks.describe()
# Out:
#        average_rating        isbn13    num_pages  ratings_count  \
# count        6.000000  6.000000e+00     6.000000       6.000000
# mean         4.753333  9.780672e+12  1322.666667   24122.666667
# std          0.041793  1.850730e+08  1421.230828   13261.232622
# min          4.710000  9.780440e+12    96.000000    3613.000000
# 25%          4.722500  9.780515e+12   176.000000   17492.500000
# 50%          4.745000  9.780741e+12   816.000000   26058.500000
# 75%          4.775000  9.780812e+12  2381.500000   31220.250000
# max          4.820000  9.780836e+12  3342.000000   41428.000000
#
#        text_reviews_count
# count            6.000000
# mean           430.000000
# std            351.679968
# min             85.000000
# 25%            195.500000
# 50%            296.500000
# 75%            681.750000
# max            930.000000

# %% [markdown]
# ## Part 4

# %% [markdown]
# ### 4.1 Which are 7 most popular book languages(language_code) in this dataset?
# Print the `language_code` and count of the 7 highest occuring languages in the dataset. (Hint - `<dataframe>.<column-name>` gives you a series. With this, can you use [value_counts()](https://https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html) to get the answer? ) [1pt]

# %%
books.language_code.value_counts().head(7)
# Out:
# eng      8908
# en-US    1408
# spa       218
# en-GB     214
# fre       144
# ger        99
# jpn        46
# Name: language_code, dtype: int64

# %% [markdown]
# ### 4.2 Find number of books that have an average rating within 2 standard deviations from mean average rating of the entire dataset.
# [Standard deviation](https://https://en.wikipedia.org/wiki/Standard_deviation) tells you how spread out the data is. It is a measure of how far each observed value is from the mean. In any distribution, about 95% of values will be within 2 standard deviations of the mean.
# Hence, for the given task, we want to find the number of books who have an average rating from `mean-2*std_dev` to `mean+2*std_dev`. [1pt]

# %%
std_dev = books['average_rating'].std()
avg = books['average_rating'].mean()

within_std = books[books.average_rating.gt(avg - 2*std_dev) & books.average_rating.lt(avg + 2*std_dev)]
len(within_std)
# Out:
# 10854

# %% [markdown]
# ### 4.3 Find books with language code as 'ger' and whose publication date is between 2001 and 2005. (Optional)
# (Hint - How do we get the year from the publication date in its current form? Can we use [pd.to_datetime](https://https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) to extract what we need for this task?)

# %%
filtered_ger_data =  books.loc[(books['language_code'] == 'ger')]
filtered_ger_data['publication_date'] = pd.to_datetime(filtered_ger_data['publication_date'], format="%m/%d/%Y")
date_start = datetime.date(2001, 1, 1)
date_end = datetime.date(2004, 12, 31)
a = filtered_ger_data[(filtered_ger_data['publication_date'].dt.date > date_start) & (filtered_ger_data['publication_date'].dt.date < date_end)]
a
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                     title  \
# bookID
# 2875                                    Wenn Engel fallen
# 3316                            Die Brücke über die Drina
# 3966                                 Die Hyperion-Gesänge
# 4624                    Chronik eines angekündigten Todes
# 5412                        The Stand: Das letzte Gefecht
# 7054    Ein Gentleman für Mma Ramotswe (No. 1 Ladies' ...
# 7055    Ein Koch für Mma Ramotswe (No. 1 Ladies' Detec...
# 7536                             Anleitung zum Zickigsein
# 9987                                       Naokos Lächeln
# 10013            Erläuterungen Zu Max Frisch  Homo Faber
# 11520                          Endymion: Pforten der Zeit
# 12018                             Exzession (Culture  #5)
# 14081                        Utena: Revolutionary Girl 01
# 14641                                Der Fänger im Roggen
# 14883                     Die Wahrheit der letzten Stunde
# 14886                           Die Hexen von Salem Falls
# 14888                        In einer regnerischen Nacht.
# 15948                                      Weg der Träume
# 16093                                         Fuselfieber
# 17761         Hafen des Unglücks (Aubrey/Maturin Book 11)
# 17762   Manöver um Feuerland (The Far Side of the Worl...
# 17778   Gefahr im Roten Meer (Treason's Harbour) (Aubr...
# 18383                                           Jane Eyre
# 19792                     Power: Die 48 Gesetze Der Macht
# 20394                                         Der Prophet
# 21947           Bevor es Nacht wird. Ein Leben in Havanna
# 22718                                          Pusteblume
# 22736                                      Yeats ist tot!
# 22745                 Auszeit für Engel Walsh Family  #3)
# 23439                                Die Farbe von Wasser
# 25257                Mein Urgroßvater  die Helden und ich
# 25368                              Die Umarmung des Todes
# 25740                                           Der Golem
# 28947                                       Familienalbum
# 29140                                          Melliandra
# 30272                  Schattenkuss (Meredith Gentry  #1)
# 30284                Nachtschwärmer (Meredith Gentry  #2)
# 30413                                            Betrogen
# 30446                                        Schöne Lügen
# 32115                                        Ali und Nino
# 33704   Der Buchhändler aus Kabul: Eine Familiengeschi...
# 33751                                     Die Naschkatzen
# 33775                                  Kopfüber ins Glück
# 33821                                          Wolfsbrut.
# 37824       Balzac und die kleine chinesische Schneiderin
# 39004                          Die Tagebücher einer Nanny
# 41903   Das Zauberer-Handbuch - Die Magische Welt der ...
# 41908   Harry Potter und der Gefangene von Askaban (Ha...
# 41911   Harry Potter und der Gefangene von Askaban (Ha...
# 42706           Fish & Chips (The Barrytown Trilogie  #3)
# 42728                           Rover rettet Weihnachten.
# 42738                                         The Snapper
# 43407                                Alles ist erleuchtet
# 43499         Die Flucht der Waisen (Die Orphan-Saga  #5)
# 43503   Dornen des Glücks (Das Erbe von Foxworth Hall ...
# 45113   Der lohfarbene Mann (Die zweiten Chroniken von...
# 45449                     Artemis Fowl (Artemis Fowl  #1)
#
#                                                   authors  average_rating  \
# bookID
# 2875                                      Tracy Chevalier            3.58
# 3316                            Ivo Andrić/Ernst E. Jonas            4.33
# 3966                           Dan Simmons/Joachim Körber            4.42
# 4624             Gabriel García Márquez/Curt Meyer-Clason            3.97
# 5412                          Stephen King/Joachim Körber            4.34
# 7054                               Alexander McCall Smith            3.96
# 7055                               Alexander McCall Smith            3.98
# 7536                                        Laurie Notaro            3.88
# 9987                         Haruki Murakami/Ursula Gräfe            4.03
# 10013                                    Bernd Matzkowski            3.60
# 11520                                         Dan Simmons            4.17
# 12018                        Iain M. Banks/Irene Bonhorst            4.21
# 14081                                         Chiho Saito            3.83
# 14641                        J.D. Salinger/Eike Schönfeld            3.80
# 14883                                        Jodi Picoult            3.80
# 14886                                        Jodi Picoult            3.82
# 14888                                        Jodi Picoult            3.58
# 15948                  Nicholas Sparks/Maja Ueberle-Pfaff            4.03
# 16093                         David Sedaris/Harry Rowohlt            3.79
# 17761                                     Patrick O'Brian            4.41
# 17762                                     Patrick O'Brian            4.45
# 17778                                     Patrick O'Brian            4.38
# 18383                                    Charlotte Brontë            4.12
# 19792      Robert Greene/Birgit Brandau/Hartmut Schickert            4.18
# 20394                                       Kahlil Gibran            4.23
# 21947                                     Reinaldo Arenas            4.17
# 22718                                        Marian Keyes            3.81
# 22736   Joseph O'Connor/Diethard Herles/Pauline McLynn...            3.40
# 22745                                        Marian Keyes            3.75
# 23439                                     James   McBride            4.09
# 25257                                         James Krüss            4.30
# 25368                                       Natsuo Kirino            3.92
# 25740                               Isaac Bashevis Singer            3.75
# 28947                                       Kate Atkinson            3.96
# 29140                                          J.V. Jones            3.79
# 30272                                 Laurell K. Hamilton            4.01
# 30284                                 Laurell K. Hamilton            4.06
# 30413                                        Sandra Brown            3.92
# 30446                            Rachel Ryan/Sandra Brown            3.60
# 32115                                         Kurban Said            3.92
# 33704                                      Åsne Seierstad            3.76
# 33751                                     Jennifer Crusie            3.94
# 33775                                         Anna Maxted            3.54
# 33821                                      Nelson DeMille            3.85
# 37824                                           Dai Sijie            3.64
# 39004                        Emma McLaughlin/Nicola Kraus            3.42
# 41903                                  Allan Zola Kronzek            4.04
# 41908                             J.K. Rowling/Rufus Beck            4.56
# 41911                                        J.K. Rowling            4.56
# 42706                    Roddy Doyle/Renate Orth-Guttmann            3.94
# 42728                             Roddy Doyle/Brian Ajhar            4.12
# 42738                                         Roddy Doyle            3.93
# 43407             Jonathan Safran Foer/Dirk van Gunsteren            3.90
# 43499            V.C. Andrews/Susanne Althoetmar-Smarczyk            3.77
# 43503                         V.C. Andrews/Michael Görden            3.77
# 45113                                          Robin Hobb            4.31
# 45449                        Eoin Colfer/Claudia Feldmann            3.84
#
#               isbn         isbn13 language_code    num_pages  ratings_count  \
# bookID
# 2875    3471772537  9783471772539           ger          384              6
# 3316    3518399608  9783518399606           ger          407              9
# 3966    3453215281  9783453215283           ger         1456            141
# 4624    3462031953  9783462031959           ger          119             11
# 5412    3404134117  9783404134113           ger         1227            256
# 7054    3485009024  9783485009027           ger          238             11
# 7055    3485009601  9783485009607           ger          240              2
# 7536    3404149475  9783404149476           ger          254              2
# 9987    3442730503  9783442730506           ger          416           1254
# 10013   3804417833  9783804417830           ger          104              4
# 11520   3442353920  9783442353927           ger          672              3
# 12018   3453196791  9783453196797           ger          655             24
# 14081   3551768617  9783551768612           ger          192             14
# 14641   3462032186  9783462032185           ger          270             33
# 14883   3404145844  9783404145843           ger          684              7
# 14886   3822505870  9783822505878           ger          472             23
# 14888   3492236553  9783492236553           ger          512              1
# 15948   3453861906  9783453861909           ger          352              8
# 16093   3453198255  9783453198258           ger          320             14
# 17761   3548256422  9783548256429           ger          354              6
# 17762   3548254438  9783548254432           ger          478              8
# 17778   3548254357  9783548254357           ger          412              7
# 18383   3717519646  9783717519645           ger          784            432
# 19792   3423362480  9783423362481           ger          536             39
# 20394   3530268038  9783530268034           ger           95              9
# 21947   3423129867  9783423129862           ger          400             16
# 22718   3453189345  9783453189348           ger          560             59
# 22736   3548603254  9783548603254           ger          332             11
# 22745   3453868579  9783453868571           ger          477             16
# 23439   342661278X  9783426612781           ger          317             38
# 25257   3551552711  9783551552716           ger          250             16
# 25368   3442309174  9783442309177           ger          607              6
# 25740   349175710X  9783491757103           ger           64              2
# 28947   3453212630  9783453212633           ger          507              2
# 29140   3404204077  9783404204076           ger          734              5
# 30272   3442356911  9783442356911           ger          573             22
# 30284   3442358957  9783442358953           ger          586             13
# 30413   3764501359  9783764501358           ger          512              5
# 30446   3442354994  9783442354993           ger          255             13
# 32115   3548601316  9783548601311           ger          304             39
# 33704   3546003306  9783546003308           ger          301              1
# 33751   3442448964  9783442448968           ger          480             15
# 33775   3442454085  9783442454082           ger          512              0
# 33821   3548253814  9783548253817           ger          470              2
# 37824   3492238696  9783492238694           ger          200            343
# 39004   3442545536  9783442545537           ger          344             38
# 41903   3442451531  9783442451531           ger          304             39
# 41908   3895849618  9783895849619           ger           13            313
# 41911   355155210X  9783551552105           ger          448             30
# 42706   3596153026  9783596153022           ger          314              2
# 42728   3570127214  9783570127216           ger          160              1
# 42738   3596153034  9783596153039           ger          217             26
# 43407   3462032178  9783462032178           ger          384             39
# 43499   3442354560  9783442354566           ger          349              2
# 43503   3442552966  9783442552962           ger          412              5
# 45113   3404283368  9783404283361           ger          880              8
# 45449   3548603203  9783548603209           ger          240            428
#
#         text_reviews_count publication_date  \
# bookID
# 2875                     1       2002-02-01
# 3316                     0       2003-03-01
# 3966                    11       2002-08-01
# 4624                     1       2002-08-01
# 5412                    16       2003-09-01
# 7054                     3       2002-02-01
# 7055                     2       2003-02-01
# 7536                     1       2003-08-01
# 9987                    63       2003-02-01
# 10013                    0       2002-05-11
# 11520                    0       2001-02-01
# 12018                    2       2002-03-01
# 14081                    0       2003-02-01
# 14641                    6       2003-02-20
# 14883                    2       2001-08-01
# 14886                    3       2002-08-01
# 14888                    0       2003-02-01
# 15948                    2       2003-04-01
# 16093                    0       2002-04-01
# 17761                    0       2002-10-01
# 17762                    0       2002-06-01
# 17778                    0       2002-05-01
# 18383                   26       2001-03-01
# 19792                    4       2001-10-01
# 20394                    0       2001-09-01
# 21947                    2       2002-07-01
# 22718                    0       2001-05-01
# 22736                    2       2003-04-01
# 22745                    1       2003-02-01
# 23439                    1       2001-02-01
# 25257                    1       2002-12-01
# 25368                    2       2003-03-01
# 25740                    0       2001-02-01
# 28947                    0       2002-01-01
# 29140                    0       2001-03-01
# 30272                    0       2002-04-02
# 30284                    0       2003-05-01
# 30413                    0       2003-02-01
# 30446                    1       2001-09-01
# 32115                    2       2002-02-01
# 33704                    0       2003-02-01
# 33751                    1       2001-04-01
# 33775                    0       2003-02-01
# 33821                    1       2002-04-01
# 37824                   15       2003-07-01
# 39004                    2       2003-02-01
# 41903                    1       2001-11-01
# 41908                    8       2002-08-31
# 41911                    2       2001-04-01
# 42706                    0       2002-10-01
# 42728                    0       2002-09-01
# 42738                    5       2002-09-01
# 43407                    4       2003-02-20
# 43499                    0       2002-03-01
# 43503                    0       2002-09-01
# 45113                    0       2003-04-01
# 45449                   24       2003-05-01
#
#                                                 publisher
# bookID
# 2875                                                 List
# 3316                                             Suhrkamp
# 3966                                                Heyne
# 4624                                 Kiepenheuer & Witsch
# 5412                                         Bastei Lübbe
# 7054                                        Nymphenburger
# 7055                                        Nymphenburger
# 7536                                                Lübbe
# 9987                                                  btb
# 10013                                            C. Bange
# 11520                               Blanvalet Taschenbuch
# 12018                                               Heyne
# 14081                                             Carlsen
# 14641                                Kiepenheuer & Witsch
# 14883                                               Lübbe
# 14886                            Kabel  Verlag GmbH Ernst
# 14888                                               Piper
# 15948                                               Heyne
# 16093                                            Diana TB
# 17761   Ullstein Buchverlage GmbH & Co. KG / Ullstein Tas
# 17762                                         Ullstein Tb
# 17778                                         Ullstein Tb
# 18383                                      Manesse Verlag
# 19792                        Deutscher Taschenbuch Verlag
# 20394                                            Benziger
# 21947                                                 dtv
# 22718                                               Heyne
# 22736                                    List Taschenbuch
# 22745                                               Heyne
# 23439                                       Droemer Knaur
# 25257                                             Carlsen
# 25368                                            Goldmann
# 25740                                              Patmos
# 28947                                               Heyne
# 29140                                               Lübbe
# 30272                        Blanvalet Taschenbuch Verlag
# 30284                        Blanvalet Taschenbuch Verlag
# 30413                               Blanvalet Verlag GmbH
# 30446                                            Goldmann
# 32115                                                List
# 33704                                     Claassen Verlag
# 33751                                     Goldmann Verlag
# 33775                                            Goldmann
# 33821                                            Ullstein
# 37824                                   Piper Taschenbuch
# 39004                                            Goldmann
# 41903                                            Goldmann
# 41908                                   Dhv der Hörverlag
# 41911                                             Carlsen
# 42706                          Fischer Taschenbuch Verlag
# 42728                          Omnibus Hc Bei Bertelsmann
# 42738                                          Fischer TB
# 43407                                Kiepenheuer & Witsch
# 43499                                            Goldmann
# 43503                                            Goldmann
# 45113                                               Lübbe
# 45449                                                List

# %%
filtered_ger_data =  books.loc[(books['language_code'] == 'ger')]

# %%
filtered_ger_data
# Out:
#                                                     title  \
# bookID
# 2875                                    Wenn Engel fallen
# 2896             Das Parfum. Die Geschichte eines Mörders
# 3084                                  April  May und June
# 3316                            Die Brücke über die Drina
# 3966                                 Die Hyperion-Gesänge
# ...                                                   ...
# 43407                                Alles ist erleuchtet
# 43499         Die Flucht der Waisen (Die Orphan-Saga  #5)
# 43503   Dornen des Glücks (Das Erbe von Foxworth Hall ...
# 45113   Der lohfarbene Mann (Die zweiten Chroniken von...
# 45449                     Artemis Fowl (Artemis Fowl  #1)
#
#                                          authors  average_rating        isbn  \
# bookID
# 2875                             Tracy Chevalier            3.58  3471772537
# 2896                             Patrick Süskind            4.02  3257228007
# 3084                         Elizabeth von Arnim            3.88  345833422X
# 3316                   Ivo Andrić/Ernst E. Jonas            4.33  3518399608
# 3966                  Dan Simmons/Joachim Körber            4.42  3453215281
# ...                                          ...             ...         ...
# 43407    Jonathan Safran Foer/Dirk van Gunsteren            3.90  3462032178
# 43499   V.C. Andrews/Susanne Althoetmar-Smarczyk            3.77  3442354560
# 43503                V.C. Andrews/Michael Görden            3.77  3442552966
# 45113                                 Robin Hobb            4.31  3404283368
# 45449               Eoin Colfer/Claudia Feldmann            3.84  3548603203
#
#                isbn13 language_code    num_pages  ratings_count  \
# bookID
# 2875    9783471772539           ger          384              6
# 2896    9783257228007           ger          321           9674
# 3084    9783458334224           ger           88              0
# 3316    9783518399606           ger          407              9
# 3966    9783453215283           ger         1456            141
# ...               ...           ...          ...            ...
# 43407   9783462032178           ger          384             39
# 43499   9783442354566           ger          349              2
# 43503   9783442552962           ger          412              5
# 45113   9783404283361           ger          880              8
# 45449   9783548603209           ger          240            428
#
#         text_reviews_count publication_date             publisher
# bookID
# 2875                     1         2/1/2002                  List
# 2896                   343         6/1/1994              Diogenes
# 3084                     0         4/1/1995      Insel  Frankfurt
# 3316                     0         3/1/2003              Suhrkamp
# 3966                    11         8/1/2002                 Heyne
# ...                    ...              ...                   ...
# 43407                    4        2/20/2003  Kiepenheuer & Witsch
# 43499                    0         3/1/2002              Goldmann
# 43503                    0         9/1/2002              Goldmann
# 45113                    0         4/1/2003                 Lübbe
# 45449                   24         5/1/2003                  List
#
# [99 rows x 11 columns]
